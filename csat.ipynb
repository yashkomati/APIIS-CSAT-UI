# %%
import requests
import zipfile
import io
import os
import pandas as pd
import datetime
import time

def get_qualtrics_survey_data(dir_save_survey, survey_id):# dir_save_survey is the directory to which these exported files are to be saved.
   
    # Setting user Parameters
    api_token = "nEOlIxeWbcgAkcAbtk9uD8ZyT0YnCQV9AIIRQCcL"
    file_format = "csv"
    data_center = 'amazoneu.syd1' # "<Organization ID>.<Datacenter ID>"
    # Setting static parameters
    request_check_progress = 0
    progress_status = "in progress"
    base_url = "https://{0}.qualtrics.com/API/v3/responseexports/".format(data_center)
    headers = {
        "content-type": "application/json",
        "x-api-token": api_token,
    }
    # Step 1: Creating Data Export
    download_request_url = base_url
    download_request_payload = '{"format":"csv","useLabels": true ,"surveyId":"' + survey_id + '"}' # you can set useLabels:True to get responses in text format
    download_request_response = requests.request("POST", download_request_url, data=download_request_payload, headers=headers)
    progress_id = download_request_response.json()["result"]["id"]
    # print(download_request_response.text)
    # Step 2: Checking on Data Export Progress and waiting until export is ready
    while request_check_progress < 100 and progress_status != "complete":
        request_check_url = base_url + progress_id
        request_check_response = requests.request("GET", request_check_url, headers=headers)
        request_check_progress = request_check_response.json()["result"]["percentComplete"]
    # Step 3: Downloading file
    request_download_url = base_url + progress_id + '/file'
    request_download = requests.request("GET", request_download_url, headers=headers, stream=True)
    # Step 4: Unzipping the file
    zipfile.ZipFile(io.BytesIO(request_download.content)).extractall(dir_save_survey)
    print('Downloaded qualtrics survey')
path = "C:\\Users\\komatiyk\\Downloads\\Qualtrics Weekly Files"

# definining the suvery ID's with Specalist Names
Gurramr = "SV_0Ai7eAuueB6M6gJ"
ddlc = "SV_26alR8n753kAbyu"
dhahiman = "SV_8qdBdGLpsZRHAjA"
Fbhagat = "SV_9mn7lVJCPPAXNTn"
keziaidi = "SV_afMqjeuQ0UOg1qS"
khandh = "SV_8AmcjQKwidXNGG9"
komatiyk = "SV_eRHKjxVDveyIPoG"
mohlipsa = "SV_8w5mrVpJpX5RB6m"
parniv = "SV_6JqeQjoUW0D6RmK"
pratvel = "SV_9nSSDCPpLdaykf4"
Premalatha = "SV_29mXA0vS5qh5HqC"
prkujh= "SV_4HoXXHRb9ptxWbc"
prsrivas= "SV_42bdrRgDB7KUAiW"
rajchat= "SV_7ai49aIbpdjClnw"
tatii = "SV_efHw2haEtbUs7yK"
tgganesa = "SV_5bh19yBpdd1MF3o"
list = [ddlc, dhahiman, Fbhagat, keziaidi, komatiyk, mohlipsa, parniv, pratvel, Premalatha, prkujh, prsrivas, rajchat,tatii,tgganesa]
[get_qualtrics_survey_data(dir_save_survey = path, survey_id = i) for i in list]
# Out:
# Downloaded qualtrics survey
# Downloaded qualtrics survey
# Downloaded qualtrics survey
# Downloaded qualtrics survey
# Downloaded qualtrics survey
# Downloaded qualtrics survey
# Downloaded qualtrics survey
# Downloaded qualtrics survey
# Downloaded qualtrics survey
# Downloaded qualtrics survey
# Downloaded qualtrics survey
# Downloaded qualtrics survey
# Downloaded qualtrics survey
# Downloaded qualtrics survey
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
ddlc = pd.read_csv("Technical Onboarding CSAT- 2022(ddlc).csv")
dhahiman = pd.read_csv("Technical Onboarding CSAT- 2022(dhahiman).csv")
Fbhagat = pd.read_csv("Technical Onboarding CSAT- 2022(Fbhagat).csv")
keziaidi = pd.read_csv("Technical Onboarding CSAT- 2022(keziaidi).csv")
komatiyk = pd.read_csv("Technical Onboarding CSAT- 2022(komatiyk).csv")
mohlipsa = pd.read_csv("Technical Onboarding CSAT- 2022(mohlipsa).csv")
parniv = pd.read_csv("Technical Onboarding CSAT- 2022(parniv).csv")
pratvel = pd.read_csv("Technical Onboarding CSAT- 2022(pratvel).csv")
Premalatha = pd.read_csv("Technical Onboarding CSAT- 2022(Premalatha).csv")
prkujh = pd.read_csv("Technical Onboarding CSAT- 2022(prkujh).csv")
rajchat = pd.read_csv("Technical Onboarding CSAT- 2022(rajchat).csv")
tgganesa = pd.read_csv("Technical Onboarding CSAT- 2022(tgganesa).csv")
tatii = pd.read_csv("Technical Onboarding CSAT- 2022(tatii).csv")

#List1 = (
#     Fbhagat = pd.read_csv("Technical Onboarding CSAT- 2022(Fbhagat).csv"),Premalatha = pd.read_csv("Technical Onboarding CSAT- 2022(Premalatha).csv"),ddlc = pd.read_csv("Technical Onboarding CSAT- 2022(ddlc).csv"),dhahiman = pd.read_csv("Technical Onboarding CSAT- 2022(dhahiman).csv"),keziaidi = pd.read_csv("Technical Onboarding CSAT- 2022(keziaidi).csv"),komatiyk = pd.read_csv("Technical Onboarding CSAT- 2022(komatiyk).csv"),mohlipsa = pd.read_csv("Technical Onboarding CSAT- 2022(mohlipsa).csv"),parniv = pd.read_csv("Technical Onboarding CSAT- 2022(parniv).csv"),pratvel = pd.read_csv("Technical Onboarding CSAT- 2022(pratvel).csv"),prkujh = pd.read_csv("Technical Onboarding CSAT- 2022(prkujh).csv"),
#     rajchat = pd.read_csv("Technical Onboarding CSAT- 2022(rajchat).csv"),tatii = pd.read_csv("Technical Onboarding CSAT- 2022(tatii).csv"),tgganesa = pd.read_csv("Technical Onboarding CSAT- 2022(tgganesa).csv")
# )

# %%
# # Names defined as in Astro Report: 'Harish Ganesan', 'Lakshmi Pratyusha Velamakanni', 'Farah Bhagat',
#        'Niveditha Parvatha', 'PRAKASH JHA', 'Premalatha maddirala',
#        'Himanshu Dhami', 'Yashwant Komati', 'Dilip Chavali',
#        'Indra Tatikonda', 'Rajarshi Chatterjee', 'Lipsa Mohanty',
#        'KEZIA IDIKKULA MUTHALALY'

## By doing the below we are adding a column SPOC with the Specalist's name against the feedback received and removing the extra header rows on individual file.

ddlc['SPOC'] = "DILIP CHAVALI"
ddlc.drop([0,1],inplace= True)
Fbhagat['SPOC'] = "FARAH BHAGAT"
Fbhagat.drop([0,1],inplace= True)
dhahiman['SPOC'] = "HIMANSHU DHAMI"
dhahiman.drop([0,1],inplace= True)
keziaidi['SPOC'] = "KEZIA IDIKKULA MUTHALALY"
keziaidi.drop([0,1],inplace= True)
komatiyk['SPOC'] = "YASHWANT KOMATI"
komatiyk.drop([0,1],inplace= True)
mohlipsa['SPOC'] = "LIPSA MOHANTY"
mohlipsa.drop([0,1],inplace= True)
parniv['SPOC'] = "NIVEDITHA PARVATHA"
parniv.drop([0,1],inplace= True)
pratvel['SPOC'] = "LAKSHMI PRATYUSHA VELAMAKANNI"
pratvel.drop([0,1],inplace= True)
Premalatha['SPOC'] = "PREMALATHA MADDIRALA"
Premalatha.drop([0,1],inplace= True)
prkujh['SPOC'] = "PRAKASH JHA"
prkujh.drop([0,1],inplace= True)
rajchat['SPOC'] = "RAJARSHI CHATTERJEE"
rajchat.drop([0,1],inplace= True)
tgganesa['SPOC'] = "HARISH GANESAN"
tgganesa.drop([0,1],inplace= True)
tatii['SPOC'] = "INDRA TATIKONDA"
tatii.drop([0,1],inplace= True)

# %%
df_merged = pd.concat([ddlc,dhahiman, Fbhagat, keziaidi, komatiyk, mohlipsa, parniv, pratvel, Premalatha, prkujh, rajchat, tgganesa, tatii])

df_merged # All Feedbacks
# Out:
#            ResponseID ResponseSet     IPAddress            StartDate  \
# 2   R_3maDsWCzZBHBNUu         NaN  91.241.18.19  2021-10-11 10:02:35
# 3   R_C36gknwR1sf3SPD         NaN   3.88.93.236  2021-11-18 14:08:39
# 4   R_2YldibFOkrIilqh         NaN    52.95.75.9  2021-11-24 11:46:50
# 5   R_3jd1JKYRO0XKwUF         NaN  93.56.31.152  2021-11-24 17:05:45
# 6   R_1EhQUTTXRKWcd2S         NaN  87.200.21.74  2021-11-25 08:19:20
# ..                ...         ...           ...                  ...
# 45  R_1DIr2SUuQmDmDSZ         NaN  78.134.72.11  2023-05-02 11:43:36
# 46  R_1jdgmhL8zo6tYpL         NaN  51.155.23.77  2023-05-16 11:56:15
# 47  R_PXwToEDr3GX9xU5         NaN  54.239.6.185  2023-06-15 10:56:12
# 48  R_1EbaMaD93pgY6Td         NaN  54.239.6.184  2023-06-26 13:33:29
# 49  R_6MAhGZ5EWELerW9         NaN   94.89.28.10  2023-06-27 08:59:52
#
#                 EndDate RecipientLastName RecipientFirstName RecipientEmail  \
# 2   2021-10-11 10:05:58               NaN                NaN            NaN
# 3   2021-11-18 14:12:19               NaN                NaN            NaN
# 4   2021-11-24 11:56:01               NaN                NaN            NaN
# 5   2021-11-24 17:09:03               NaN                NaN            NaN
# 6   2021-11-25 08:21:01               NaN                NaN            NaN
# ..                  ...               ...                ...            ...
# 45  2023-05-02 11:44:51               NaN                NaN            NaN
# 46  2023-05-16 12:16:19               NaN                NaN            NaN
# 47  2023-06-15 10:56:59               NaN                NaN            NaN
# 48  2023-06-26 13:40:48               NaN                NaN            NaN
# 49  2023-06-27 09:00:31               NaN                NaN            NaN
#
#    ExternalDataReference Finished  ...          Q2_1  \
# 2                    NaN        1  ...       3 -Fair
# 3                    NaN        1  ...  5- Excellent
# 4                    NaN        1  ...  5- Excellent
# 5                    NaN        1  ...  5- Excellent
# 6                    NaN        1  ...       4- Good
# ..                   ...      ...  ...           ...
# 45                   NaN        1  ...  5- Excellent
# 46                   NaN        1  ...  5- Excellent
# 47                   NaN        1  ...       4- Good
# 48                   NaN        1  ...  5- Excellent
# 49                   NaN        1  ...  5- Excellent
#
#                            Q3  \
# 2              A11OKMLEOWRUTY
# 3              A1Y1NMNJFO9AZH
# 4              A2WJJHFR3EZX13
# 5              A39JLZTLGJEAS9
# 6   lenish@dynamicsstream.com
# ..                        ...
# 45             A29BCDAL77UPK2
# 46             A1023IQIDP1IRB
# 47                          d
# 48              AJKTJJ9LD2M9I
# 49             A3CCGCDRNSK3MY
#
#                                                    Q4    LocationLatitude  \
# 2                                                 NaN   59.89830017089844
# 3                                                 NaN  39.046905517578125
# 4   Dilip has been very helpful and approachable t...  19.074798583984375
# 5                                                 NaN   41.89039611816406
# 6   Still, our project work is going on. We should...    25.2633056640625
# ..                                                ...                 ...
# 45                                                NaN             45.7333
# 46  Absolutely fantastic support.  Indra was very ...             51.6445
# 47                                                NaN             50.1188
# 48  Perfect support. Was making time to jump in a ...             50.1188
# 49                                                NaN             43.7891
#
#      LocationLongitude LocationAccuracy             SPOC Score-sum  \
# 2   30.261795043945312               -1    DILIP CHAVALI       NaN
# 3   -77.49030303955078               -1    DILIP CHAVALI       NaN
# 4    72.88560485839844               -1    DILIP CHAVALI       NaN
# 5   12.512603759765625               -1    DILIP CHAVALI       NaN
# 6    55.30870056152344               -1    DILIP CHAVALI       NaN
# ..                 ...              ...              ...       ...
# 45              8.5626               -1  INDRA TATIKONDA       NaN
# 46             -3.9775               -1  INDRA TATIKONDA       NaN
# 47              8.6843               -1  INDRA TATIKONDA       NaN
# 48              8.6843               -1  INDRA TATIKONDA       NaN
# 49             11.2356               -1  INDRA TATIKONDA       NaN
#
#    Score-weightedAvg Score-weightedStdDev
# 2                NaN                  NaN
# 3                NaN                  NaN
# 4                NaN                  NaN
# 5                NaN                  NaN
# 6                NaN                  NaN
# ..               ...                  ...
# 45               NaN                  NaN
# 46               NaN                  NaN
# 47               NaN                  NaN
# 48               NaN                  NaN
# 49               NaN                  NaN
#
# [711 rows x 23 columns]

# %%
#Dropping unneccesary columns and renaming certain columns for easy reference.

merged_mod = df_merged.drop(columns=['ResponseID','ResponseSet','IPAddress','Score-sum','Score-weightedAvg','Score-weightedStdDev'])

merged_mod.rename(columns={'StartDate': 'Start_Date', 'EndDate': 'End_date','RecipientLastName': 'Specalist_Name', 'Q1': 'Rating of the overall Support','Q2_1': 'Knowledge of SP-API products & Services','Q2_2': 'Ability to communicate clearly','Q3': 'Merchant_Token', 'Q4': 'Comments'}, inplace=True)

merged_mod[['Start_Date','End_date']]= merged_mod[['Start_Date','End_date']].apply(pd.to_datetime)

merged_mod['Merchant_Token'].fillna('0')

merged_mod
# Out:
#             Start_Date            End_date Specalist_Name RecipientFirstName  \
# 2  2021-10-11 10:02:35 2021-10-11 10:05:58            NaN                NaN
# 3  2021-11-18 14:08:39 2021-11-18 14:12:19            NaN                NaN
# 4  2021-11-24 11:46:50 2021-11-24 11:56:01            NaN                NaN
# 5  2021-11-24 17:05:45 2021-11-24 17:09:03            NaN                NaN
# 6  2021-11-25 08:19:20 2021-11-25 08:21:01            NaN                NaN
# ..                 ...                 ...            ...                ...
# 45 2023-05-02 11:43:36 2023-05-02 11:44:51            NaN                NaN
# 46 2023-05-16 11:56:15 2023-05-16 12:16:19            NaN                NaN
# 47 2023-06-15 10:56:12 2023-06-15 10:56:59            NaN                NaN
# 48 2023-06-26 13:33:29 2023-06-26 13:40:48            NaN                NaN
# 49 2023-06-27 08:59:52 2023-06-27 09:00:31            NaN                NaN
#
#    RecipientEmail ExternalDataReference Finished Status  \
# 2             NaN                   NaN        1      0
# 3             NaN                   NaN        1      0
# 4             NaN                   NaN        1      0
# 5             NaN                   NaN        1      0
# 6             NaN                   NaN        1      0
# ..            ...                   ...      ...    ...
# 45            NaN                   NaN        1      0
# 46            NaN                   NaN        1      0
# 47            NaN                   NaN        1      0
# 48            NaN                   NaN        1      0
# 49            NaN                   NaN        1      0
#
#    Rating of the overall Support Ability to communicate clearly  \
# 2                        4- Good                   5- Excellent
# 3                   5- Excellent                   5- Excellent
# 4                   5- Excellent                   5- Excellent
# 5                        4- Good                   5- Excellent
# 6                        4- Good                   5- Excellent
# ..                           ...                            ...
# 45                  5- Excellent                   5- Excellent
# 46                  5- Excellent                   5- Excellent
# 47                       4- Good                        4- Good
# 48                  5- Excellent                   5- Excellent
# 49                  5- Excellent                   5- Excellent
#
#    Knowledge of SP-API products & Services             Merchant_Token  \
# 2                                  3 -Fair             A11OKMLEOWRUTY
# 3                             5- Excellent             A1Y1NMNJFO9AZH
# 4                             5- Excellent             A2WJJHFR3EZX13
# 5                             5- Excellent             A39JLZTLGJEAS9
# 6                                  4- Good  lenish@dynamicsstream.com
# ..                                     ...                        ...
# 45                            5- Excellent             A29BCDAL77UPK2
# 46                            5- Excellent             A1023IQIDP1IRB
# 47                                 4- Good                          d
# 48                            5- Excellent              AJKTJJ9LD2M9I
# 49                            5- Excellent             A3CCGCDRNSK3MY
#
#                                              Comments    LocationLatitude  \
# 2                                                 NaN   59.89830017089844
# 3                                                 NaN  39.046905517578125
# 4   Dilip has been very helpful and approachable t...  19.074798583984375
# 5                                                 NaN   41.89039611816406
# 6   Still, our project work is going on. We should...    25.2633056640625
# ..                                                ...                 ...
# 45                                                NaN             45.7333
# 46  Absolutely fantastic support.  Indra was very ...             51.6445
# 47                                                NaN             50.1188
# 48  Perfect support. Was making time to jump in a ...             50.1188
# 49                                                NaN             43.7891
#
#      LocationLongitude LocationAccuracy             SPOC
# 2   30.261795043945312               -1    DILIP CHAVALI
# 3   -77.49030303955078               -1    DILIP CHAVALI
# 4    72.88560485839844               -1    DILIP CHAVALI
# 5   12.512603759765625               -1    DILIP CHAVALI
# 6    55.30870056152344               -1    DILIP CHAVALI
# ..                 ...              ...              ...
# 45              8.5626               -1  INDRA TATIKONDA
# 46             -3.9775               -1  INDRA TATIKONDA
# 47              8.6843               -1  INDRA TATIKONDA
# 48              8.6843               -1  INDRA TATIKONDA
# 49             11.2356               -1  INDRA TATIKONDA
#
# [711 rows x 17 columns]

# %%
# Creating a column "Key" which is a combination of Merchant Token + the Speclalist's name, which would help us compare the feedbacks with cases on Astro

merged_mod['Key'] = merged_mod.Merchant_Token.str.cat(merged_mod.SPOC)

merged_mod['Ability to communicate clearly'] = merged_mod['Ability to communicate clearly'].astype(str).str.split('-').str[0].astype(int)
merged_mod['Knowledge of SP-API products & Services'] = merged_mod['Knowledge of SP-API products & Services'].astype(str).str.split('-').str[0].astype(int)

merged_mod['Average CSAT'] = (merged_mod['Ability to communicate clearly'] + merged_mod['Knowledge of SP-API products & Services']) / 2

merged_mod
# Out:
#             Start_Date            End_date Specalist_Name RecipientFirstName  \
# 2  2021-10-11 10:02:35 2021-10-11 10:05:58            NaN                NaN
# 3  2021-11-18 14:08:39 2021-11-18 14:12:19            NaN                NaN
# 4  2021-11-24 11:46:50 2021-11-24 11:56:01            NaN                NaN
# 5  2021-11-24 17:05:45 2021-11-24 17:09:03            NaN                NaN
# 6  2021-11-25 08:19:20 2021-11-25 08:21:01            NaN                NaN
# ..                 ...                 ...            ...                ...
# 45 2023-05-02 11:43:36 2023-05-02 11:44:51            NaN                NaN
# 46 2023-05-16 11:56:15 2023-05-16 12:16:19            NaN                NaN
# 47 2023-06-15 10:56:12 2023-06-15 10:56:59            NaN                NaN
# 48 2023-06-26 13:33:29 2023-06-26 13:40:48            NaN                NaN
# 49 2023-06-27 08:59:52 2023-06-27 09:00:31            NaN                NaN
#
#    RecipientEmail ExternalDataReference Finished Status  \
# 2             NaN                   NaN        1      0
# 3             NaN                   NaN        1      0
# 4             NaN                   NaN        1      0
# 5             NaN                   NaN        1      0
# 6             NaN                   NaN        1      0
# ..            ...                   ...      ...    ...
# 45            NaN                   NaN        1      0
# 46            NaN                   NaN        1      0
# 47            NaN                   NaN        1      0
# 48            NaN                   NaN        1      0
# 49            NaN                   NaN        1      0
#
#    Rating of the overall Support  Ability to communicate clearly  \
# 2                        4- Good                               5
# 3                   5- Excellent                               5
# 4                   5- Excellent                               5
# 5                        4- Good                               5
# 6                        4- Good                               5
# ..                           ...                             ...
# 45                  5- Excellent                               5
# 46                  5- Excellent                               5
# 47                       4- Good                               4
# 48                  5- Excellent                               5
# 49                  5- Excellent                               5
#
#     Knowledge of SP-API products & Services             Merchant_Token  \
# 2                                         3             A11OKMLEOWRUTY
# 3                                         5             A1Y1NMNJFO9AZH
# 4                                         5             A2WJJHFR3EZX13
# 5                                         5             A39JLZTLGJEAS9
# 6                                         4  lenish@dynamicsstream.com
# ..                                      ...                        ...
# 45                                        5             A29BCDAL77UPK2
# 46                                        5             A1023IQIDP1IRB
# 47                                        4                          d
# 48                                        5              AJKTJJ9LD2M9I
# 49                                        5             A3CCGCDRNSK3MY
#
#                                              Comments    LocationLatitude  \
# 2                                                 NaN   59.89830017089844
# 3                                                 NaN  39.046905517578125
# 4   Dilip has been very helpful and approachable t...  19.074798583984375
# 5                                                 NaN   41.89039611816406
# 6   Still, our project work is going on. We should...    25.2633056640625
# ..                                                ...                 ...
# 45                                                NaN             45.7333
# 46  Absolutely fantastic support.  Indra was very ...             51.6445
# 47                                                NaN             50.1188
# 48  Perfect support. Was making time to jump in a ...             50.1188
# 49                                                NaN             43.7891
#
#      LocationLongitude LocationAccuracy             SPOC  \
# 2   30.261795043945312               -1    DILIP CHAVALI
# 3   -77.49030303955078               -1    DILIP CHAVALI
# 4    72.88560485839844               -1    DILIP CHAVALI
# 5   12.512603759765625               -1    DILIP CHAVALI
# 6    55.30870056152344               -1    DILIP CHAVALI
# ..                 ...              ...              ...
# 45              8.5626               -1  INDRA TATIKONDA
# 46             -3.9775               -1  INDRA TATIKONDA
# 47              8.6843               -1  INDRA TATIKONDA
# 48              8.6843               -1  INDRA TATIKONDA
# 49             11.2356               -1  INDRA TATIKONDA
#
#                                        Key  Average CSAT
# 2              A11OKMLEOWRUTYDILIP CHAVALI           4.0
# 3              A1Y1NMNJFO9AZHDILIP CHAVALI           5.0
# 4              A2WJJHFR3EZX13DILIP CHAVALI           5.0
# 5              A39JLZTLGJEAS9DILIP CHAVALI           5.0
# 6   lenish@dynamicsstream.comDILIP CHAVALI           4.5
# ..                                     ...           ...
# 45           A29BCDAL77UPK2INDRA TATIKONDA           5.0
# 46           A1023IQIDP1IRBINDRA TATIKONDA           5.0
# 47                        dINDRA TATIKONDA           4.0
# 48            AJKTJJ9LD2M9IINDRA TATIKONDA           5.0
# 49           A3CCGCDRNSK3MYINDRA TATIKONDA           5.0
#
# [711 rows x 19 columns]

# %%
merged_mod.to_csv('Merged_FB_File.csv') # Converting the aggregated feedbacks to a CSV file

# %%
astro = pd.read_csv('DataAstro.csv') # Importing astro report without paid
astro = astro.rename(columns={'key': 'Key'})
astro[['create_date','listing_complete_date', 'integration_start_date','handoff_date']]= astro[['create_date','listing_complete_date', 'integration_start_date','handoff_date']].apply(pd.to_datetime)
astro
# Out:
#        run_date  case_number  merchant_customer_id    encrypted_id  \
# 0     6/12/2023      1106256          4.789394e+10  A3GQ5ONWIQ9PID
# 1     6/12/2023      1563542          2.867124e+10   AB36Q4XFJK40H
# 2     6/12/2023      1567266          5.100887e+08  A32URRHD2J995G
# 3     6/12/2023      1098047          1.471784e+10  A3HOPLRF61I8Z5
# 4     6/12/2023      1573435          4.614223e+07  A2PVIXJF9UTT7R
# ...         ...          ...                   ...             ...
# 1231  6/12/2023      1394064          1.859954e+10  A2HCFN68KH3Q5J
# 1232  6/12/2023      1321856          7.244474e+10  A2GIWHDB2WEDIG
# 1233  6/12/2023      1354558          2.856930e+11  A3SPBNBRY5GT11
# 1234  6/12/2023      1080474          1.670540e+11  A3VS3C5O1Q39VF
# 1235  6/12/2023      1356607          7.913905e+09  A2AAP1ZNM6SPO6
#
#                                      Key                   account_name  \
# 0          A3GQ5ONWIQ9PIDIndra Tatikonda               FindTape (Japan)
# 1      AB36Q4XFJK40HPremalatha Maddirala                  Wifi Stock UK
# 2     A32URRHD2J995GPremalatha Maddirala              ReinigungsBerater
# 3            A3HOPLRF61I8Z5Dilip Chavali                    Yuca LTD UK
# 4      A2PVIXJF9UTT7RRajarshi Chatterjee         GourmetGiftBaskets.com
# ...                                  ...                            ...
# 1231          A2HCFN68KH3Q5JFarah Bhagat        Pera Limonera Lifestyle
# 1232   A2GIWHDB2WEDIGRajarshi Chatterjee                    GoedGepickt
# 1233       A3SPBNBRY5GT11Yashwant Komati  متجر أسراركو للتسوق  asrar-co
# 1234         A3VS3C5O1Q39VFDilip Chavali           Luca Vanucci Firenze
# 1235       A2AAP1ZNM6SPO6Yashwant Komati                    Eiz Pty Ltd
#
#      astro_mkp                               type_of_request     status  \
# 0           JP     Technical Onboarding Request - New Seller  Completed
# 1           UK     Technical Onboarding Request - New Seller  Completed
# 2           DE                                     Push Back  Cancelled
# 3           UK     Technical Onboarding Request - New Seller  Completed
# 4           US     Technical Onboarding Request - New Seller        WIP
# ...        ...                                           ...        ...
# 1231        ES  Technical Onboarding Request - Reintegration        WIP
# 1232        UK     Technical Onboarding Request - New Seller  Cancelled
# 1233        SA     Technical Onboarding Request - New Seller  Cancelled
# 1234        UK                                     Push Back  Cancelled
# 1235        AU     Technical Onboarding Request - New Seller  Completed
#
#      create_date listing_complete_date                 owner  \
# 0     2021-07-21            2021-09-01       Indra Tatikonda
# 1     2023-04-20            2023-06-01  Premalatha Maddirala
# 2     2023-05-04                   NaT  Premalatha Maddirala
# 3     2021-06-08            2021-11-26         Dilip Chavali
# 4     2023-05-18                   NaT   Rajarshi Chatterjee
# ...          ...                   ...                   ...
# 1231  2023-01-17                   NaT          Farah Bhagat
# 1232  2022-05-20                   NaT   Rajarshi Chatterjee
# 1233  2022-09-12                   NaT       Yashwant Komati
# 1234  2021-03-16                   NaT         Dilip Chavali
# 1235  2022-09-19            2022-08-31       Yashwant Komati
#
#      integration_start_date            status_notes handoff_date
# 0                2021-08-17         DSR - Migration   2021-08-02
# 1                2023-04-20            MIGRATION_AB   2023-04-20
# 2                       NaT                     DSR   2023-05-08
# 3                2021-05-12          3PD_INTEGRATOR   2021-05-12
# 4                2023-05-18            migration_1P   2023-05-18
# ...                     ...                     ...          ...
# 1231             2023-01-20  DSR-SP_API INTEGRATION   2023-01-20
# 1232             2022-05-30                     DSR   2022-05-20
# 1233                    NaT                     NaN   2022-09-13
# 1234                    NaT                     NaN   2021-03-31
# 1235             2022-07-25      DSR_INTEGRATOR_AES   2022-07-15
#
# [1236 rows x 15 columns]

# %%
astro_paid = pd.read_excel('Astro_Paid.xlsx', sheet_name='Paid')
astro_paid = astro_paid.rename(columns={'key': 'Key'})
astro_paid[['create_date','listing_complete_date', 'integration_start_date','handoff_date']]= astro_paid[['create_date','listing_complete_date', 'integration_start_date','handoff_date']].apply(pd.to_datetime)
astro_paid
# Out:
#       run_date  case_number  merchant_customer_id    encrypted_id  \
# 0   2023-06-12       163175            1211291772   AUNGYH863E97M
# 1   2023-06-12       182768           47590974012  A3Q145GG5GOJFD
# 2   2023-06-12       220004             757310623  A175O6N7UW1356
# 3   2023-06-12       247216            7647118235  A27DL0OMONAIX2
# 4   2023-06-12       261671           14816121112  A3I7IG61W9TCJR
# ..         ...          ...                   ...             ...
# 137 2023-06-12       493052           78178837412  A16KNVL00HJUQF
# 138 2023-06-12       493051           70655247112  A2I72QKJSAQX9K
# 139 2023-06-12       476544            1206131742  A18FY9ILZV4767
# 140 2023-06-12       476514          121075172312  A34GF78PIKBRV5
# 141 2023-06-12       476322             508544291   ALYY2EOZQ7QUK
#
#                                         Key                 account_name  \
# 0                AUNGYH863E97MDilip Chavali                    vidaXL IT
# 1          A3Q145GG5GOJFDNiveditha Parvatha                 Joyería TOUS
# 2                 A175O6N7UW1356PRAKASH JHA  S&O Handelsgesellschaft mbH
# 3             A27DL0OMONAIX2Yashwant Komati                    Juvenilis
# 4               A3I7IG61W9TCJRLipsa Mohanty              LULUBUY S.A.R.L
# ..                                      ...                          ...
# 137      A16KNVL00HJUQFPremalatha Maddirala                      Tudetic
# 138              A2I72QKJSAQX9KFarah Bhagat                        wilko
# 139  A18FY9ILZV4767KEZIA IDIKKULA MUTHALALY        Alice's Garden France
# 140            A34GF78PIKBRV5Himanshu Dhami                       Nivian
# 141                ALYY2EOZQ7QUKPRAKASH JHA                     MEDIMOPS
#
#     astro_mkp                               type_of_request     status  \
# 0          EU     Technical Onboarding Request - New Seller  Completed
# 1          EU     Technical Onboarding Request - New Seller  Completed
# 2          EU  Technical Onboarding Request - Reintegration        WIP
# 3          EU  Technical Onboarding Request - Reintegration  Completed
# 4          EU  Technical Onboarding Request - Reintegration  Completed
# ..        ...                                           ...        ...
# 137        EU     Technical Onboarding Request - New Seller        WIP
# 138        EU  Technical Onboarding Request - Reintegration  Submitted
# 139        EU     Technical Onboarding Request - New Seller        WIP
# 140        EU  Technical Onboarding Request - Reintegration        WIP
# 141        EU  Technical Onboarding Request - Reintegration        WIP
#
#             create_date listing_complete_date                     owner  \
# 0   2022-05-11 00:00:00   2023-04-24 16:22:00             Dilip Chavali
# 1   2022-06-14 00:00:00   2023-03-10 00:00:00        Niveditha Parvatha
# 2   2022-08-08 00:00:00                   NaT               PRAKASH JHA
# 3   2022-09-13 20:48:00   2023-04-24 16:33:00           Yashwant Komati
# 4   2022-09-29 21:44:00   2023-04-12 01:13:00             Lipsa Mohanty
# ..                  ...                   ...                       ...
# 137 2023-05-22 15:21:00                   NaT      Premalatha Maddirala
# 138 2023-05-22 15:20:00                   NaT              Farah Bhagat
# 139 2023-05-03 20:50:00                   NaT  KEZIA IDIKKULA MUTHALALY
# 140 2023-05-03 19:54:00                   NaT            Himanshu Dhami
# 141 2023-05-03 14:39:00                   NaT               PRAKASH JHA
#
#     integration_start_date status_notes handoff_date
# 0      2022-05-11 20:51:00         PAID          NaT
# 1      2022-06-14 02:34:00         PAID          NaT
# 2      2022-08-08 15:45:00         Paid          NaT
# 3      2022-09-13 20:48:00         PAID          NaT
# 4      2022-09-29 21:44:00         PAID          NaT
# ..                     ...          ...          ...
# 137    2023-05-22 15:21:00         Paid          NaT
# 138    2023-05-22 15:20:00         Paid          NaT
# 139    2023-05-03 20:50:00         Paid          NaT
# 140    2023-05-03 19:54:00         Paid          NaT
# 141    2023-05-03 14:39:00         Paid          NaT
#
# [142 rows x 15 columns]

# %%
astro_combined = pd.concat([astro,astro_paid], ignore_index=True)

astro_combined.to_csv('astro_combined.csv')

# %%
# Creating a column "Key" which is a combination of Merchant Token + the Speclalist's name, which would help us compare the feedbacks with cases on Astro
astro_combined['Key'] = astro_combined['Key'].str.upper()
astro_combined['owner'] = astro_combined['owner'].str.upper()
#astro['Key'] = astro.encrypt_id.str.cat(astro.owner)

#Converting the data type of Complete date and start date to Time Format, which is currently is a pandas series format.

# # astro['listing_complete_date'] = pd.to_datetime(astro['listing_complete_date'], format='%Y-%m-%d')
# # astro['create_date'] = pd.to_datetime(astro['create_date'], format='%Y-%m-%d')
astro_combined['merchant_customer_id'].fillna(0)
astro_combined[['run_date','integration_start_date','handoff_date','listing_complete_date','create_date']]= astro[['run_date','integration_start_date','handoff_date','listing_complete_date','create_date']].apply(pd.to_datetime)

astro_combined.head()
# Out:
#     run_date  case_number  merchant_customer_id    encrypted_id  \
# 0 2023-06-12      1106256          4.789394e+10  A3GQ5ONWIQ9PID
# 1 2023-06-12      1563542          2.867124e+10   AB36Q4XFJK40H
# 2 2023-06-12      1567266          5.100887e+08  A32URRHD2J995G
# 3 2023-06-12      1098047          1.471784e+10  A3HOPLRF61I8Z5
# 4 2023-06-12      1573435          4.614223e+07  A2PVIXJF9UTT7R
#
#                                   Key            account_name astro_mkp  \
# 0       A3GQ5ONWIQ9PIDINDRA TATIKONDA        FindTape (Japan)        JP
# 1   AB36Q4XFJK40HPREMALATHA MADDIRALA           Wifi Stock UK        UK
# 2  A32URRHD2J995GPREMALATHA MADDIRALA       ReinigungsBerater        DE
# 3         A3HOPLRF61I8Z5DILIP CHAVALI             Yuca LTD UK        UK
# 4   A2PVIXJF9UTT7RRAJARSHI CHATTERJEE  GourmetGiftBaskets.com        US
#
#                              type_of_request     status create_date  \
# 0  Technical Onboarding Request - New Seller  Completed  2021-07-21
# 1  Technical Onboarding Request - New Seller  Completed  2023-04-20
# 2                                  Push Back  Cancelled  2023-05-04
# 3  Technical Onboarding Request - New Seller  Completed  2021-06-08
# 4  Technical Onboarding Request - New Seller        WIP  2023-05-18
#
#   listing_complete_date                 owner integration_start_date  \
# 0            2021-09-01       INDRA TATIKONDA             2021-08-17
# 1            2023-06-01  PREMALATHA MADDIRALA             2023-04-20
# 2                   NaT  PREMALATHA MADDIRALA                    NaT
# 3            2021-11-26         DILIP CHAVALI             2021-05-12
# 4                   NaT   RAJARSHI CHATTERJEE             2023-05-18
#
#       status_notes handoff_date
# 0  DSR - Migration   2021-08-02
# 1     MIGRATION_AB   2023-04-20
# 2              DSR   2023-05-08
# 3   3PD_INTEGRATOR   2021-05-12
# 4     migration_1P   2023-05-18

# %%
filtered_astro = astro_combined[(astro_combined['listing_complete_date'].dt.year == 2023) | (astro_combined['listing_complete_date'].isnull()) & astro_combined['status'].isin(['Completed', 'WIP', 'Awaiting Information', 'Submitted'])]

# %%
# Pivot table to show cases details against each individual

astro_pivot = pd.pivot_table(filtered_astro, index =['owner'], values=['case_number'], columns=['status'], aggfunc= 'count', fill_value = 0)

astro_pivot.to_csv('astro_pivot.csv')

# %%
# gives all 2022 cases with all the statuses
#astro_all_22 = astro.loc[(astro['create_date'] >= '2022-01-01')]

#(astro.loc[(astro['listing_complete_date'] >= '2022-01-01') & (astro['listing_complete_date'] < '2022-12-31')]) 

#astro_all_22.to_csv('astro_all_22.csv')

# %%
astro_completed= filtered_astro[filtered_astro['status'] =='Completed']

# astro_completed.head(3)

#astro_completed_22 = (astro_completed.loc[(astro_completed['listing_complete_date'].between('2022-01-01','2022-12-31'))])

#astro_completed_22 = (astro_completed.loc[(astro_completed['listing_complete_date'] >= '2022-01-01') & (astro_completed['listing_complete_date'] < '2022-12-31')])

astro_completed.to_csv('astro_completed_23.csv')

astro_completed.head(3) # gives all cases that are completed
# Out:
#     run_date  case_number  merchant_customer_id    encrypted_id  \
# 1 2023-06-12      1563542          2.867124e+10   AB36Q4XFJK40H
# 5 2023-06-12      1345198          1.361387e+10  A39RQLAOUKITT0
# 7 2023-06-12      1563737          2.601602e+10   A19KSF3YAVQFA
#
#                                       Key  \
# 1       AB36Q4XFJK40HPREMALATHA MADDIRALA
# 5  A39RQLAOUKITT0KEZIA IDIKKULA MUTHALALY
# 7               A19KSF3YAVQFAFARAH BHAGAT
#
#                                 account_name astro_mkp  \
# 1                              Wifi Stock UK        UK
# 5  Marks Electrical Ltd. (Agent of Euronics)        UK
# 7                         Allianz Assistance        UK
#
#                                 type_of_request     status create_date  \
# 1     Technical Onboarding Request - New Seller  Completed  2023-04-20
# 5  Technical Onboarding Request - Reintegration  Completed  2022-08-11
# 7     Technical Onboarding Request - New Seller  Completed  2023-04-21
#
#   listing_complete_date                     owner integration_start_date  \
# 1            2023-06-01      PREMALATHA MADDIRALA             2023-04-20
# 5            2023-02-01  KEZIA IDIKKULA MUTHALALY             2022-08-18
# 7            2023-04-21              FARAH BHAGAT             2022-09-09
#
#    status_notes handoff_date
# 1  MIGRATION_AB   2023-04-20
# 5           DSR   2022-08-12
# 7  INSURANCE_FR   2022-09-09

# %%
look_up = pd.merge(astro_completed,merged_mod[['Key','SPOC','Average CSAT']], on = 'Key', how= 'left') # Merges and compares feedbacks
# compares owner = spoc, if yes, makes its Feedback 'Yes'. Else: 'No'
look_up.loc[look_up['owner']== look_up['SPOC'], 'Feedback_Received'] = 'Yes'
look_up.loc[look_up['owner']!= look_up['SPOC'], 'Feedback_Received'] = 'No'
look_up['status_notes'] = look_up['status_notes'].str.upper()
look_up = look_up.drop_duplicates(subset=["case_number"], keep='last')
look_up.to_csv('look_up.csv')

# %%
cases_due = look_up[look_up.Feedback_Received == 'No']

cases_due.to_csv('cases_due.csv')

# %%
tmp_df = look_up[look_up['listing_complete_date'].notnull()]
tmp_df = look_up
tmp_df = tmp_df[['Feedback_Received','owner','Average CSAT']].copy()
pivot_table = tmp_df.pivot_table(
    index=['owner'],
    columns=['Feedback_Received',],
    values=['Feedback_Received',],
    aggfunc={'Feedback_Received': ['count'], 'Average CSAT': ['mean']}
)
pivot_table.columns = ['_'.join([str(c) for c in c_list]) for c_list in pivot_table.columns.values]
look_up_pivot = pivot_table.reset_index()
# Changed Feedback_Received count Yes to dtype int
look_up_pivot['Feedback_Received_count_Yes'] = look_up_pivot['Feedback_Received_count_Yes'].fillna(0).astype('int')
# Changed Feedback_Received count No to dtype int
look_up_pivot['Feedback_Received_count_No'] = look_up_pivot['Feedback_Received_count_No'].fillna(0).astype('int')
# Reordered column Feedback_Received count Yes
look_up_pivot_columns = [col for col in look_up_pivot.columns if col != 'Feedback_Received_count_Yes']
look_up_pivot_columns.insert(1, 'Feedback_Received_count_Yes')
look_up_pivot = look_up_pivot[look_up_pivot_columns]
# Renamed columns APIIS_Specalist
look_up_pivot.rename(columns={'owner': 'APIIS_Specalist'}, inplace=True)
# Renamed columns Feedback_Received (Yes)
look_up_pivot.rename(columns={'Feedback_Received_count_Yes': 'Feedback_Received (Yes)'}, inplace=True)
# Renamed columns Feedback_Received (No)
look_up_pivot.rename(columns={'Feedback_Received_count_No': 'Feedback_Received (No)'}, inplace=True)
# Added column Total Completed Cases
look_up_pivot.insert(3, 'Total Completed Cases', 0)
# Set formula of Total Completed Cases
look_up_pivot['Total Completed Cases'] = look_up_pivot['Feedback_Received (Yes)'] + look_up_pivot['Feedback_Received (No)']
# Added column CSAT Response Rate (%)
look_up_pivot.insert(4, 'CSAT Response Rate (%)', 0)
# Set formula of CSAT Response Rate (%)
look_up_pivot['CSAT Response Rate (%)'] = (look_up_pivot['Feedback_Received (Yes)'] / look_up_pivot['Total Completed Cases']) * 100
# Format the CSAT Response Rate (%) column to have two decimal places
look_up_pivot['CSAT Response Rate (%)'] = look_up_pivot['CSAT Response Rate (%)'].apply(lambda x: '{:.2f}'.format(x))
# Added column average csat
look_up_pivot = look_up_pivot.drop(columns=['Average CSAT_mean_No'])
look_up_pivot['Average CSAT_mean_Yes'] = look_up_pivot['Average CSAT_mean_Yes'].apply(lambda x: '{:.2f}'.format(x))
look_up_pivot = look_up_pivot.rename(columns={'Average CSAT_mean_Yes': 'Average CSAT'})
# Reordered column Feedback Due (No)
look_up_pivot_columns = [col for col in look_up_pivot.columns if col != 'Feedback_Received (No)']
look_up_pivot_columns.insert(2, 'Feedback_Received (No)')
look_up_pivot = look_up_pivot[look_up_pivot_columns]
# Set formula of CSAT Response Rate (%)
look_up_pivot.to_csv('CSAT_RR_Pivot.csv')
look_up_pivot
# Out:
#                   APIIS_Specalist  Feedback_Received (Yes)  \
# 0                   DILIP CHAVALI                       17
# 1                    FARAH BHAGAT                        4
# 2                  HARISH GANESAN                        4
# 3                  HIMANSHU DHAMI                        4
# 4                 INDRA TATIKONDA                        3
# 5        KEZIA IDIKKULA MUTHALALY                        9
# 6   LAKSHMI PRATYUSHA VELAMAKANNI                        7
# 7                   LIPSA MOHANTY                       16
# 8              NIVEDITHA PARVATHA                        9
# 9                     PRAKASH JHA                        7
# 10           PREMALATHA MADDIRALA                        8
# 11            RAJARSHI CHATTERJEE                        3
# 12                YASHWANT KOMATI                        2
#
#     Feedback_Received (No)  Total Completed Cases CSAT Response Rate (%)  \
# 0                       11                     28                  60.71
# 1                       11                     15                  26.67
# 2                        2                      6                  66.67
# 3                       10                     14                  28.57
# 4                        9                     12                  25.00
# 5                       10                     19                  47.37
# 6                       13                     20                  35.00
# 7                        9                     25                  64.00
# 8                        7                     16                  56.25
# 9                       15                     22                  31.82
# 10                       8                     16                  50.00
# 11                      21                     24                  12.50
# 12                      10                     12                  16.67
#
#    Average CSAT
# 0          4.85
# 1          5.00
# 2          4.50
# 3          4.75
# 4          4.33
# 5          4.83
# 6          4.93
# 7          4.88
# 8          4.67
# 9          5.00
# 10         4.75
# 11         5.00
# 12         4.75

# %%
tmp_df_1 = filtered_astro[['owner', 'status']].copy()
pivot_table = tmp_df_1.pivot_table(
    index=['owner'],
    columns=['status'],
    values=['status'],
    aggfunc={'status': ['count']}
)
pivot_table.columns = [ '_'.join([str(c) for c in c_list]) for c_list in pivot_table.columns.values ]
filtered_astro_pivot = pivot_table.reset_index()
# Changed status count Awaiting Information to dtype int
filtered_astro_pivot['status_count_Awaiting Information'] = filtered_astro_pivot['status_count_Awaiting Information'].fillna(0).astype('int')
# # Changed status count Cancelled to dtype int
filtered_astro_pivot['status_count_Cancelled'] = filtered_astro_pivot['status_count_Cancelled'].fillna(0).astype('int')
# # Changed status count Completed to dtype int
filtered_astro_pivot['status_count_Completed'] = filtered_astro_pivot['status_count_Completed'].fillna(0).astype('int')
# # Changed status count Submitted to dtype int
filtered_astro_pivot['status_count_Submitted'] = filtered_astro_pivot['status_count_Submitted'].fillna(0).astype('int')
# # Changed status count WIP to dtype int
filtered_astro_pivot['status_count_WIP'] = filtered_astro_pivot['status_count_WIP'].fillna(0).astype('int')
# # Renamed columns APIIS_Specalist
filtered_astro_pivot.rename(columns={'owner': 'APIIS_Specalist'}, inplace=True)
# # Renamed columns Awatiting Information
filtered_astro_pivot.rename(columns={'status_count_Awaiting Information': 'Awaiting_Information'}, inplace=True)
# # Renamed columns Cancelled
filtered_astro_pivot.rename(columns={'status_count_Cancelled': 'Cancelled'}, inplace=True)
# # Renamed columns Completed
filtered_astro_pivot.rename(columns={'status_count_Completed': 'Completed'}, inplace=True)
# # Renamed columns Submitted
filtered_astro_pivot.rename(columns={'status_count_Submitted': 'Submitted'}, inplace=True)
# # Renamed columns WIP
filtered_astro_pivot.rename(columns={'status_count_WIP': 'WIP'}, inplace=True)
# # Reordered column Submitted
filtered_astro_pivot_columns = [col for col in filtered_astro_pivot.columns if col != 'Submitted']
filtered_astro_pivot_columns.insert(1, 'Submitted')
filtered_astro_pivot = filtered_astro_pivot[filtered_astro_pivot_columns]
# # Reordered column WIP
filtered_astro_pivot_columns = [col for col in filtered_astro_pivot.columns if col != 'WIP']
filtered_astro_pivot_columns.insert(3, 'WIP')
filtered_astro_pivot = filtered_astro_pivot[filtered_astro_pivot_columns]
filtered_astro_pivot.insert(6, 'Total Cases', 0)
filtered_astro_pivot['Total Cases'] = filtered_astro_pivot['Submitted'] + filtered_astro_pivot['Awaiting_Information']+ filtered_astro_pivot['WIP'] + filtered_astro_pivot['Cancelled'] + filtered_astro_pivot['Completed']
#filtered_astro_pivot[] = sum(filtered_astro_pivot['Submitted'],filtered_astro_pivot['Awaiting_Information'],filtered_astro_pivot['WIP'],filtered_astro_pivot['Cancelled'],filtered_astro_pivot['Completed'])
filtered_astro_pivot
filtered_astro_pivot.to_csv('Case_Level_Metrics_Pivot.csv')

# %%
tmp_df_1 = look_up[look_up['listing_complete_date'].notnull()]
tmp_df_1= look_up[look_up['status_notes'].str.contains('PAID' or 'Paid', na=False, regex=False)]
#tmp_df_1 = look_up
tmp_df_1 = tmp_df_1[['Feedback_Received','owner','Average CSAT']].copy()
pivot_table_1 = tmp_df_1.pivot_table(
    index=['owner'],
    columns=['Feedback_Received',],
    values=['Feedback_Received',],
    aggfunc={'Feedback_Received': ['count'], 'Average CSAT': ['mean']}
)
pivot_table_1.columns = ['_'.join([str(c) for c in c_list]) for c_list in pivot_table_1.columns.values]
look_up_pivot_paid = pivot_table_1.reset_index()
# Changed Feedback_Received count Yes to dtype int
look_up_pivot_paid['Feedback_Received_count_Yes'] = look_up_pivot_paid['Feedback_Received_count_Yes'].fillna(0).astype('int')
# Changed Feedback_Received count No to dtype int
look_up_pivot_paid['Feedback_Received_count_No'] = look_up_pivot_paid['Feedback_Received_count_No'].fillna(0).astype('int')
# Reordered column Feedback_Received count Yes
look_up_pivot_paid_columns = [col for col in look_up_pivot_paid.columns if col != 'Feedback_Received_count_Yes']
look_up_pivot_paid_columns.insert(1, 'Feedback_Received_count_Yes')
look_up_pivot_paid = look_up_pivot_paid[look_up_pivot_paid_columns]
# Renamed columns APIIS_Specalist
look_up_pivot_paid.rename(columns={'owner': 'APIIS_Specalist'}, inplace=True)
# Renamed columns Feedback_Received (Yes)
look_up_pivot_paid.rename(columns={'Feedback_Received_count_Yes': 'Feedback_Received (Yes)'}, inplace=True)
# Renamed columns Feedback_Received (No)
look_up_pivot_paid.rename(columns={'Feedback_Received_count_No': 'Feedback_Received (No)'}, inplace=True)
# Added column Total Completed Cases
look_up_pivot_paid.insert(3, 'Total Completed Cases', 0)
# Set formula of Total Completed Cases
look_up_pivot_paid['Total Completed Cases'] = look_up_pivot_paid['Feedback_Received (Yes)'] + look_up_pivot_paid['Feedback_Received (No)']
# Added column CSAT Response Rate (%)
look_up_pivot_paid.insert(4, 'CSAT Response Rate (%)', 0)
# Set formula of CSAT Response Rate (%)
look_up_pivot_paid['CSAT Response Rate (%)'] = (look_up_pivot_paid['Feedback_Received (Yes)'] / look_up_pivot_paid['Total Completed Cases']) * 100
# Format the CSAT Response Rate (%) column to have two decimal places
look_up_pivot_paid['CSAT Response Rate (%)'] = look_up_pivot_paid['CSAT Response Rate (%)'].apply(lambda x: '{:.2f}'.format(x))
# Added column average csat
#look_up_pivot_paid = look_up_pivot_paid.drop(columns=['Average CSAT_mean_No'])
look_up_pivot_paid['Average CSAT_mean_Yes'] = look_up_pivot_paid['Average CSAT_mean_Yes'].apply(lambda x: '{:.2f}'.format(x))
look_up_pivot_paid['Average CSAT_mean_Yes'].fillna('0')
look_up_pivot_paid = look_up_pivot_paid.rename(columns={'Average CSAT_mean_Yes': 'Average CSAT'})
# Reordered column Feedback Due (No)
look_up_pivot_paid_columns = [col for col in look_up_pivot_paid.columns if col != 'Feedback_Received (No)']
look_up_pivot_paid_columns.insert(2, 'Feedback_Received (No)')
look_up_pivot_paid = look_up_pivot_paid[look_up_pivot_paid_columns]
# Set formula of CSAT Response Rate (%)
look_up_pivot_paid.to_csv('CSAT_RR_Paid_Pivot.csv')
look_up_pivot_paid
# Out:
#                   APIIS_Specalist  Feedback_Received (Yes)  \
# 0                   DILIP CHAVALI                        6
# 1                    FARAH BHAGAT                        0
# 2                  HARISH GANESAN                        1
# 3                  HIMANSHU DHAMI                        1
# 4                 INDRA TATIKONDA                        2
# 5        KEZIA IDIKKULA MUTHALALY                        1
# 6   LAKSHMI PRATYUSHA VELAMAKANNI                        2
# 7                   LIPSA MOHANTY                        3
# 8              NIVEDITHA PARVATHA                        3
# 9                     PRAKASH JHA                        4
# 10           PREMALATHA MADDIRALA                        2
# 11            RAJARSHI CHATTERJEE                        1
# 12                YASHWANT KOMATI                        1
#
#     Feedback_Received (No) Average CSAT  Total Completed Cases  \
# 0                        1         5.00                      7
# 1                        1          nan                      1
# 2                        0         5.00                      1
# 3                        3         5.00                      4
# 4                        2         4.50                      4
# 5                        1         5.00                      2
# 6                        1         5.00                      3
# 7                        1         4.67                      4
# 8                        1         4.33                      4
# 9                        5         5.00                      9
# 10                       1         5.00                      3
# 11                       1         5.00                      2
# 12                       4         5.00                      5
#
#    CSAT Response Rate (%)
# 0                   85.71
# 1                    0.00
# 2                  100.00
# 3                   25.00
# 4                   50.00
# 5                   50.00
# 6                   66.67
# 7                   75.00
# 8                   75.00
# 9                   44.44
# 10                  66.67
# 11                  50.00
# 12                  20.00
